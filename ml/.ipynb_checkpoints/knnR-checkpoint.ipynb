# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_validation import train_test_split
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from pandas import DataFrame
from urllib2 import Request, urlopen
from json import dumps, loads

# %%
api = "http://api.parkwhiz.com/v4/quotes/?q=coordinates:41.8857256,-87.6369590&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&api_key=62d882d8cfe5680004fa849286b6ce20"

req = Request(api)
page = urlopen(req)
content = page.read()

json_data = loads(content)
json_data
# Out:
# [{u'_embedded': {u'pw:location': {u'_links': {u'curies': [{u'href': u'https://api.parkwhiz.com/v4/{rel}',
#        u'name': u'pw',
#        u'templated': True}],
#      u'pw:quotes': {u'href': u'/quotes?q=location_id:6460&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00'},
#      u'pw:reviews': {u'href': u'/locations/6460/reviews'},
#      u'self': {u'href': u'/locations/6460'},
#      u'site:purchase': None},
#     u'address1': u'180 N. Franklin St.',
#     u'city': u'Chicago',
#     u'entrances': [{u'coordinates': [41.88523011803571, -87.63557374477386]}],
#     u'id': u'6460',
#     u'name': u'Franklin & Lake Self Park',
#     u'photos': [{u'position': 1,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/gallery/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/gallery_thumb/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/hub_frontpage/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/logo/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/original/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 1080,
#         u'width': 1618},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/res_ticket/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107651/search_thumb/parkwhiz-chicago-loc6460-180-n-franklin-st-1294.jpg?1467999313',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 3,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/gallery/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 533,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/gallery_thumb/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/hub_frontpage/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/logo/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/original/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 1080,
#         u'width': 1620},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/res_ticket/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107663/search_thumb/parkwhiz-chicago-loc6460-180-n-franklin-st-1298.jpg?1467999338',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 2,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/gallery/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 800,
#         u'width': 757},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/gallery_thumb/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 100,
#         u'width': 95},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/hub_frontpage/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/logo/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 100,
#         u'width': 95},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/original/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 1142,
#         u'width': 1080},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/res_ticket/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 300,
#         u'width': 284},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/107657/search_thumb/parkwhiz-chicago-loc6460-180-n-franklin-st-1292.jpg?1467999321',
#         u'height': 130,
#         u'width': 130}}}],
#     u'state': u'IL'}},
#   u'distance': {u'straight_line': {u'feet': 417, u'meters': 127}},
#   u'end_time': u'2017-12-23T20:00:00.000-06:00',
#   u'location_id': u'6460',
#   u'max_end': u'2017-12-24T00:00:00.000-06:00',
#   u'min_start': u'2017-12-23T12:00:00.000-06:00',
#   u'name': u'',
#   u'purchase_options': [{u'_links': {u'curies': [{u'href': u'https://www.parkwhiz.com/{rel}',
#        u'name': u'site',
#        u'templated': True}],
#      u'site:purchase': {u'href': u'/find_and_book/?location_id=6460&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&pwa=ee51'}},
#     u'amenities': [{u'description': u'Covered',
#       u'enabled': True,
#       u'key': u'indoor',
#       u'name': u'Covered',
#       u'visible': True},
#      {u'description': u'Security',
#       u'enabled': True,
#       u'key': u'security',
#       u'name': u'Security',
#       u'visible': True},
#      {u'description': u'Guaranteed to be unobstructed',
#       u'enabled': True,
#       u'key': u'unobstructed',
#       u'name': u'Unobstructed',
#       u'visible': True},
#      {u'description': u'Accessible',
#       u'enabled': True,
#       u'key': u'handicap',
#       u'name': u'Accessible',
#       u'visible': True},
#      {u'description': u'Attended',
#       u'enabled': False,
#       u'key': u'attended',
#       u'name': u'Attended',
#       u'visible': True},
#      {u'description': u'Valet',
#       u'enabled': False,
#       u'key': u'valet',
#       u'name': u'Valet',
#       u'visible': False},
#      {u'description': u'Restrooms',
#       u'enabled': False,
#       u'key': u'restrooms',
#       u'name': u'Restrooms',
#       u'visible': False},
#      {u'description': u'Reentry allowed',
#       u'enabled': False,
#       u'key': u'reentry',
#       u'name': u'Reentry Allowed',
#       u'visible': True},
#      {u'description': u'Electric Car Charging',
#       u'enabled': False,
#       u'key': u'vehicle_charging',
#       u'name': u'Electric Car Charging',
#       u'visible': False},
#      {u'description': u'Printed pass',
#       u'enabled': False,
#       u'key': u'printed_pass',
#       u'name': u'Printed Pass',
#       u'visible': False}],
#     u'curation_score': 74528.24412501669,
#     u'disclaimers': [u'No Re-Entry'],
#     u'id': u'eacd788b-af09-4f53-90d7-f7b25d131381',
#     u'price': {u'USD': u'13.00'},
#     u'price_advisory': u'Lowest Price Guarantee',
#     u'pricing_segments': [{u'end_time': u'2017-12-23T20:00:00.000-06:00',
#       u'event': {},
#       u'id': 43820,
#       u'pricing_type': u'TransientPricing',
#       u'purchase_limit': -1,
#       u'space_availability': {u'status': u'available'},
#       u'start_time': u'2017-12-23T12:00:00.000-06:00'}],
#     u'space_availability': {u'status': u'available'},
#     u'validation': {u'require_license_plate': False,
#      u'validation_steps': [{u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/83139/original/validation-icons-11.png?1481660866'},
#        u'instructions': u'Scan ParkWhiz Pass at entry gate'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77149/original/validation-icons-28.png?1453405541'},
#        u'instructions': u'Park in any spot not marked "Reserved"'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/83139/original/validation-icons-11.png?1481660866'},
#        u'instructions': u'Upon departure, scan ParkWhiz Pass at exit gate'}]}}],
#   u'quote_type': u'transient',
#   u'seller_id': 652,
#   u'start_time': u'2017-12-23T12:00:00.000-06:00'},
#  {u'_embedded': {u'pw:location': {u'_links': {u'curies': [{u'href': u'https://api.parkwhiz.com/v4/{rel}',
#        u'name': u'pw',
#        u'templated': True}],
#      u'pw:quotes': {u'href': u'/quotes?q=location_id:3871&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00'},
#      u'pw:reviews': {u'href': u'/locations/3871/reviews'},
#      u'self': {u'href': u'/locations/3871'},
#      u'site:purchase': None},
#     u'address1': u'281 N. Franklin St.',
#     u'city': u'Chicago',
#     u'entrances': [{u'coordinates': [41.88593811224804, -87.6352616958502]}],
#     u'id': u'3871',
#     u'name': u'225 W. Wacker Dr. Building',
#     u'photos': [{u'position': 0,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/gallery/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/gallery_thumb/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/hub_frontpage/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/logo/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/original/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/res_ticket/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188555/search_thumb/281_N._Franklin_St.__Chicago-10.jpg?1500569079',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 1,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/gallery/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/gallery_thumb/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/hub_frontpage/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/logo/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/original/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/res_ticket/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188549/search_thumb/281_N._Franklin_St.__Chicago-9.jpg?1500569076',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 2,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/gallery/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/gallery_thumb/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/hub_frontpage/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/logo/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/original/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/res_ticket/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188543/search_thumb/281_N._Franklin_St.__Chicago-4.jpg?1500569073',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 3,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/gallery/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/gallery_thumb/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/hub_frontpage/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/logo/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/original/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/res_ticket/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188537/search_thumb/281_N._Franklin_St.__Chicago-3.jpg?1500569069',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 4,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/gallery/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/gallery_thumb/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/hub_frontpage/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/logo/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/original/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/res_ticket/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188585/search_thumb/281_N._Franklin_St.__Chicago-1.jpg?1500569095',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 5,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/gallery/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/gallery_thumb/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/hub_frontpage/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/logo/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/original/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/res_ticket/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188591/search_thumb/281_N._Franklin_St.__Chicago-2.jpg?1500569098',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 6,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/gallery/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/gallery_thumb/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/hub_frontpage/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/logo/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/original/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/res_ticket/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188573/search_thumb/281_N._Franklin_St.__Chicago-5.jpg?1500569089',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 7,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/gallery/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/gallery_thumb/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/hub_frontpage/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/logo/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/original/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/res_ticket/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188561/search_thumb/281_N._Franklin_St.__Chicago-7.jpg?1500569083',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 8,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/gallery/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/gallery_thumb/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/hub_frontpage/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/logo/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/original/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/res_ticket/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/188567/search_thumb/281_N._Franklin_St.__Chicago-8.jpg?1500569086',
#         u'height': 130,
#         u'width': 130}}}],
#     u'state': u'IL'}},
#   u'distance': {u'straight_line': {u'feet': 467, u'meters': 142}},
#   u'end_time': u'2017-12-23T20:00:00.000-06:00',
#   u'location_id': u'3871',
#   u'max_end': u'2017-12-24T00:00:00.000-06:00',
#   u'min_start': u'2017-12-23T12:00:00.000-06:00',
#   u'name': u'',
#   u'purchase_options': [{u'_links': {u'curies': [{u'href': u'https://www.parkwhiz.com/{rel}',
#        u'name': u'site',
#        u'templated': True}],
#      u'site:purchase': {u'href': u'/find_and_book/?location_id=3871&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&pwa=ee51'}},
#     u'amenities': [{u'description': u'Covered',
#       u'enabled': True,
#       u'key': u'indoor',
#       u'name': u'Covered',
#       u'visible': True},
#      {u'description': u'Guaranteed to be unobstructed',
#       u'enabled': True,
#       u'key': u'unobstructed',
#       u'name': u'Unobstructed',
#       u'visible': True},
#      {u'description': u'Accessible',
#       u'enabled': True,
#       u'key': u'handicap',
#       u'name': u'Accessible',
#       u'visible': True},
#      {u'description': u'Attended',
#       u'enabled': False,
#       u'key': u'attended',
#       u'name': u'Attended',
#       u'visible': True},
#      {u'description': u'Security',
#       u'enabled': False,
#       u'key': u'security',
#       u'name': u'Security',
#       u'visible': False},
#      {u'description': u'Valet',
#       u'enabled': False,
#       u'key': u'valet',
#       u'name': u'Valet',
#       u'visible': False},
#      {u'description': u'Restrooms',
#       u'enabled': False,
#       u'key': u'restrooms',
#       u'name': u'Restrooms',
#       u'visible': False},
#      {u'description': u'Reentry allowed',
#       u'enabled': False,
#       u'key': u'reentry',
#       u'name': u'Reentry Allowed',
#       u'visible': True},
#      {u'description': u'Electric Car Charging',
#       u'enabled': False,
#       u'key': u'vehicle_charging',
#       u'name': u'Electric Car Charging',
#       u'visible': False},
#      {u'description': u'Printed pass',
#       u'enabled': False,
#       u'key': u'printed_pass',
#       u'name': u'Printed Pass',
#       u'visible': False}],
#     u'curation_score': 75748.70438546632,
#     u'id': u'e932bb35-4fdc-49e7-b27f-a204bd9800ec',
#     u'price': {u'USD': u'9.00'},
#     u'price_advisory': u'Lowest Price Guarantee',
#     u'pricing_segments': [{u'end_time': u'2017-12-23T20:00:00.000-06:00',
#       u'event': {},
#       u'id': 217946,
#       u'pricing_type': u'TransientPricing',
#       u'purchase_limit': -1,
#       u'space_availability': {u'status': u'available'},
#       u'start_time': u'2017-12-23T12:00:00.000-06:00'}],
#     u'space_availability': {u'status': u'available'},
#     u'validation': {u'require_license_plate': False,
#      u'validation_steps': [{u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/83139/original/validation-icons-11.png?1481660866'},
#        u'instructions': u'Scan ParkWhiz Pass at entry gate'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77149/original/validation-icons-28.png?1453405541'},
#        u'instructions': u'Park in any spot not marked "Reserved"'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/83139/original/validation-icons-11.png?1481660866'},
#        u'instructions': u'Upon departure, scan ParkWhiz Pass at exit gate'}]}}],
#   u'quote_type': u'transient',
#   u'seller_id': 602,
#   u'start_time': u'2017-12-23T12:00:00.000-06:00'},
#  {u'_embedded': {u'pw:location': {u'_links': {u'curies': [{u'href': u'https://api.parkwhiz.com/v4/{rel}',
#        u'name': u'pw',
#        u'templated': True}],
#      u'pw:quotes': {u'href': u'/quotes?q=location_id:9529&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00'},
#      u'pw:reviews': {u'href': u'/locations/9529/reviews'},
#      u'self': {u'href': u'/locations/9529'},
#      u'site:purchase': None},
#     u'address1': u'319 W. Randolph St.',
#     u'city': u'Chicago',
#     u'entrances': [{u'coordinates': [41.88427161764708, -87.63602267950773]}],
#     u'id': u'9529',
#     u'name': u'319 W. Randolph - Lot',
#     u'photos': [{u'position': 2,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/gallery/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 438,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/gallery_thumb/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 55,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/hub_frontpage/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/logo/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 82,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/original/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 582,
#         u'width': 1062},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/res_ticket/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 164,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166235/search_thumb/319_W._Randolph_St.1.PNG?1494366542',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 0,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/gallery/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 439,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/gallery_thumb/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 55,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/hub_frontpage/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/logo/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 82,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/original/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 583,
#         u'width': 1063},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/res_ticket/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 165,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166241/search_thumb/319_W._Randolph_St.2.PNG?1494366596',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 1,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/gallery/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 443,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/gallery_thumb/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 55,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/hub_frontpage/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/logo/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 83,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/original/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 586,
#         u'width': 1058},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/res_ticket/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 166,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166247/search_thumb/319_W._Randolph_St.3.PNG?1494366644',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 3,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/gallery/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 440,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/gallery_thumb/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 55,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/hub_frontpage/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/logo/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 83,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/original/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 586,
#         u'width': 1065},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/res_ticket/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 165,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/166253/search_thumb/319_W._Randolph_St.4.PNG?1494366702',
#         u'height': 130,
#         u'width': 130}}}],
#     u'state': u'IL'}},
#   u'distance': {u'straight_line': {u'feet': 587, u'meters': 179}},
#   u'end_time': u'2017-12-23T20:00:00.000-06:00',
#   u'location_id': u'9529',
#   u'max_end': u'2017-12-23T23:30:00.000-06:00',
#   u'min_start': u'2017-12-23T12:00:00.000-06:00',
#   u'name': u'',
#   u'purchase_options': [{u'_links': {u'curies': [{u'href': u'https://www.parkwhiz.com/{rel}',
#        u'name': u'site',
#        u'templated': True}],
#      u'site:purchase': {u'href': u'/find_and_book/?location_id=9529&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&pwa=ee51'}},
#     u'amenities': [{u'description': u'Guaranteed to be unobstructed',
#       u'enabled': True,
#       u'key': u'unobstructed',
#       u'name': u'Unobstructed',
#       u'visible': True},
#      {u'description': u'Accessible',
#       u'enabled': True,
#       u'key': u'handicap',
#       u'name': u'Accessible',
#       u'visible': True},
#      {u'description': u'Attended',
#       u'enabled': False,
#       u'key': u'attended',
#       u'name': u'Attended',
#       u'visible': True},
#      {u'description': u'Covered',
#       u'enabled': False,
#       u'key': u'indoor',
#       u'name': u'Covered',
#       u'visible': True},
#      {u'description': u'Security',
#       u'enabled': False,
#       u'key': u'security',
#       u'name': u'Security',
#       u'visible': False},
#      {u'description': u'Valet',
#       u'enabled': False,
#       u'key': u'valet',
#       u'name': u'Valet',
#       u'visible': False},
#      {u'description': u'Restrooms',
#       u'enabled': False,
#       u'key': u'restrooms',
#       u'name': u'Restrooms',
#       u'visible': False},
#      {u'description': u'Reentry allowed',
#       u'enabled': False,
#       u'key': u'reentry',
#       u'name': u'Reentry Allowed',
#       u'visible': True},
#      {u'description': u'Electric Car Charging',
#       u'enabled': False,
#       u'key': u'vehicle_charging',
#       u'name': u'Electric Car Charging',
#       u'visible': False},
#      {u'description': u'Printed pass',
#       u'enabled': False,
#       u'key': u'printed_pass',
#       u'name': u'Printed Pass',
#       u'visible': False}],
#     u'curation_score': 78685.71892547476,
#     u'disclaimers': [u'No Oversize Vehicles. No in/out privileges.\r\n\r\nLot may become a valet, based on occupancy, customers may be asked to leave keys with attendant. Attendant is on duty Monday - Friday 6am - 8pm. When keys are left with attendant, keys must be retrieved  prior to attendant leaving at 8pm.\r\n\r\nKeys can be picked up after 8pm at the 111 N. Franklin Interpark garage office across the street (by COSI).\r\n\r\nFor immediate assistance on-site,  please call 312-578-1380\r\n\r\nIf possible, Print and display barcode on dashboard.'],
#     u'id': u'ec4c0a7f-6ee2-4c3d-8c49-76f072554ab4',
#     u'price': {u'USD': u'13.00'},
#     u'price_advisory': u'None',
#     u'pricing_segments': [{u'end_time': u'2017-12-23T20:00:00.000-06:00',
#       u'event': {},
#       u'id': 457294,
#       u'pricing_type': u'TransientPricing',
#       u'purchase_limit': -1,
#       u'space_availability': {u'status': u'available'},
#       u'start_time': u'2017-12-23T12:00:00.000-06:00'}],
#     u'space_availability': {u'status': u'available'},
#     u'validation': {u'require_license_plate': True,
#      u'validation_steps': [{u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77149/original/validation-icons-28.png?1453405541'},
#        u'instructions': u'Park in any spot not marked "Reserved"'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77185/original/validation-icons-24.png?1453405560'},
#        u'instructions': u'If an attendant is present, show ParkWhiz pass'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77167/original/validation-icons-30.png?1453405551'},
#        u'instructions': u'When unattended your ParkwhizPass is validated by your license plate'}]}}],
#   u'quote_type': u'transient',
#   u'seller_id': 652,
#   u'start_time': u'2017-12-23T12:00:00.000-06:00'},
#  {u'_embedded': {u'pw:location': {u'_links': {u'curies': [{u'href': u'https://api.parkwhiz.com/v4/{rel}',
#        u'name': u'pw',
#        u'templated': True}],
#      u'pw:quotes': {u'href': u'/quotes?q=location_id:6168&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00'},
#      u'pw:reviews': {u'href': u'/locations/6168/reviews'},
#      u'self': {u'href': u'/locations/6168'},
#      u'site:purchase': None},
#     u'address1': u'343 W. Wolfpoint Plz.',
#     u'city': u'Chicago',
#     u'entrances': [{u'coordinates': [41.88793790448945, -87.63728990220443]}],
#     u'id': u'6168',
#     u'name': u'Wolf Point Self Park',
#     u'photos': [{u'position': 0,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/gallery/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/gallery_thumb/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/hub_frontpage/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/logo/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/original/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 1080,
#         u'width': 1618},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/res_ticket/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111293/search_thumb/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4702.jpg?1469091500',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 1,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/gallery/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/gallery_thumb/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/hub_frontpage/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/logo/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/original/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 1080,
#         u'width': 1618},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/res_ticket/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/111305/search_thumb/parkwhiz-chicago-loc6168-325-w-wolfpoint-plaza-4703.jpg?1469091545',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 2,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/gallery/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/gallery_thumb/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/hub_frontpage/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/logo/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/original/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/res_ticket/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207329/search_thumb/343_W._Wolfpoint_Plz.__Chicago-2.jpg?1505647998',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 3,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/gallery/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/gallery_thumb/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/hub_frontpage/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/logo/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/original/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/res_ticket/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207347/search_thumb/343_W._Wolfpoint_Plz.__Chicago-6.jpg?1505648082',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 4,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/gallery/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/gallery_thumb/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/hub_frontpage/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/logo/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/original/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/res_ticket/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207341/search_thumb/343_W._Wolfpoint_Plz.__Chicago-7.jpg?1505648077',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 5,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/gallery/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/gallery_thumb/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/hub_frontpage/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/logo/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/original/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/res_ticket/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207335/search_thumb/343_W._Wolfpoint_Plz.__Chicago-8.jpg?1505648072',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 6,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/gallery/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/gallery_thumb/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/hub_frontpage/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/logo/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/original/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/res_ticket/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207359/search_thumb/343_W._Wolfpoint_Plz.__Chicago-9.jpg?1505648090',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 7,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/gallery/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/gallery_thumb/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/hub_frontpage/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/logo/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/original/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/res_ticket/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/207353/search_thumb/343_W._Wolfpoint_Plz.__Chicago-10.jpg?1505648086',
#         u'height': 130,
#         u'width': 130}}}],
#     u'state': u'IL'}},
#   u'distance': {u'straight_line': {u'feet': 810, u'meters': 247}},
#   u'end_time': u'2017-12-23T20:00:00.000-06:00',
#   u'location_id': u'6168',
#   u'max_end': u'2017-12-23T20:00:00.000-06:00',
#   u'min_start': u'2017-12-23T12:00:00.000-06:00',
#   u'name': u'',
#   u'purchase_options': [{u'_links': {u'curies': [{u'href': u'https://www.parkwhiz.com/{rel}',
#        u'name': u'site',
#        u'templated': True}],
#      u'site:purchase': {u'href': u'/find_and_book/?location_id=6168&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&pwa=ee51'}},
#     u'amenities': [{u'description': u'Attended',
#       u'enabled': True,
#       u'key': u'attended',
#       u'name': u'Attended',
#       u'visible': True},
#      {u'description': u'Covered',
#       u'enabled': True,
#       u'key': u'indoor',
#       u'name': u'Covered',
#       u'visible': True},
#      {u'description': u'Guaranteed to be unobstructed',
#       u'enabled': True,
#       u'key': u'unobstructed',
#       u'name': u'Unobstructed',
#       u'visible': True},
#      {u'description': u'Electric Car Charging',
#       u'enabled': True,
#       u'key': u'vehicle_charging',
#       u'name': u'Electric Car Charging',
#       u'visible': True},
#      {u'description': u'Security',
#       u'enabled': False,
#       u'key': u'security',
#       u'name': u'Security',
#       u'visible': False},
#      {u'description': u'Valet',
#       u'enabled': False,
#       u'key': u'valet',
#       u'name': u'Valet',
#       u'visible': False},
#      {u'description': u'Restrooms',
#       u'enabled': False,
#       u'key': u'restrooms',
#       u'name': u'Restrooms',
# ...
#   u'distance': {u'straight_line': {u'feet': 2597, u'meters': 791}},
#   u'end_time': u'2017-12-23T20:00:00.000-06:00',
#   u'location_id': u'1208',
#   u'max_end': u'2017-12-23T23:30:00.000-06:00',
#   u'min_start': u'2017-12-23T12:00:00.000-06:00',
#   u'name': u'',
#   u'purchase_options': [{u'_links': {u'curies': [{u'href': u'https://www.parkwhiz.com/{rel}',
#        u'name': u'site',
#        u'templated': True}],
#      u'site:purchase': {u'href': u'/find_and_book/?location_id=1208&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&pwa=ee51'}},
#     u'add_ons': {u'general': {u'options': [], u'required': False},
#      u'vehicle_size': {u'options': [{u'availability': {u'status': u'unavailable'},
#         u'end_time': u'2017-12-23T20:00:00.000-06:00',
#         u'icon': {u'position': 0,
#          u'sizes': {u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/102824/original/van.png?1465878137',
#            u'height': 500,
#            u'width': 500}}},
#         u'id': u'0c534014-7c9d-441e-8f6b-33dfbf7db0d9',
#         u'items': [u'Truck/Van'],
#         u'name': u'Oversize',
#         u'price': {u'USD': u'0.00'},
#         u'start_time': u'2017-12-23T12:00:00.000-06:00'},
#        {u'availability': {u'status': u'available'},
#         u'end_time': u'2017-12-23T20:00:00.000-06:00',
#         u'icon': {u'position': 0,
#          u'sizes': {u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/102823/original/sedan.png?1465878137',
#            u'height': 500,
#            u'width': 500}}},
#         u'id': u'4ef56f28-400e-4c3e-a400-f0ac53c46a6c',
#         u'items': [u'Coupe',
#          u'Sedan',
#          u'SUV',
#          u'Crossover',
#          u'Wagon',
#          u'Minivan',
#          u'Hatchback'],
#         u'name': u'Standard',
#         u'price': {u'USD': u'0.00'},
#         u'start_time': u'2017-12-23T12:00:00.000-06:00'}],
#       u'required': True}},
#     u'amenities': [{u'description': u'Attended',
#       u'enabled': True,
#       u'key': u'attended',
#       u'name': u'Attended',
#       u'visible': True},
#      {u'description': u'Guaranteed to be unobstructed',
#       u'enabled': True,
#       u'key': u'unobstructed',
#       u'name': u'Unobstructed',
#       u'visible': True},
#      {u'description': u'Accessible',
#       u'enabled': True,
#       u'key': u'handicap',
#       u'name': u'Accessible',
#       u'visible': True},
#      {u'description': u'Covered',
#       u'enabled': False,
#       u'key': u'indoor',
#       u'name': u'Covered',
#       u'visible': True},
#      {u'description': u'Security',
#       u'enabled': False,
#       u'key': u'security',
#       u'name': u'Security',
#       u'visible': False},
#      {u'description': u'Valet',
#       u'enabled': False,
#       u'key': u'valet',
#       u'name': u'Valet',
#       u'visible': False},
#      {u'description': u'Restrooms',
#       u'enabled': False,
#       u'key': u'restrooms',
#       u'name': u'Restrooms',
#       u'visible': False},
#      {u'description': u'Reentry allowed',
#       u'enabled': False,
#       u'key': u'reentry',
#       u'name': u'Reentry Allowed',
#       u'visible': True},
#      {u'description': u'Electric Car Charging',
#       u'enabled': False,
#       u'key': u'vehicle_charging',
#       u'name': u'Electric Car Charging',
#       u'visible': False},
#      {u'description': u'Printed pass',
#       u'enabled': False,
#       u'key': u'printed_pass',
#       u'name': u'Printed Pass',
#       u'visible': False}],
#     u'curation_score': 127677.23535905665,
#     u'disclaimers': [u'No Re-Entry\r\nNo Over-Sized Vehicles'],
#     u'id': u'2dbfcbfe-cd51-48e1-bf15-3a537e41811b',
#     u'name': u'$10',
#     u'price': {u'USD': u'10.00'},
#     u'price_advisory': u'None',
#     u'pricing_segments': [{u'end_time': u'2017-12-23T20:00:00.000-06:00',
#       u'event': {},
#       u'id': 214622,
#       u'pricing_type': u'TransientPricing',
#       u'purchase_limit': -1,
#       u'space_availability': {u'status': u'available'},
#       u'start_time': u'2017-12-23T12:00:00.000-06:00'}],
#     u'space_availability': {u'status': u'available'},
#     u'validation': {u'require_license_plate': True,
#      u'validation_steps': [{u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77149/original/validation-icons-28.png?1453405541'},
#        u'instructions': u'Park in any spot not marked "Reserved"'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77185/original/validation-icons-24.png?1453405560'},
#        u'instructions': u'If an attendant is present, show ParkWhiz pass'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77167/original/validation-icons-30.png?1453405551'},
#        u'instructions': u'When unattended your ParkwhizPass is validated by your license plate'}]}}],
#   u'quote_type': u'transient',
#   u'seller_id': 54,
#   u'start_time': u'2017-12-23T12:00:00.000-06:00'},
#  {u'_embedded': {u'pw:location': {u'_links': {u'curies': [{u'href': u'https://api.parkwhiz.com/v4/{rel}',
#        u'name': u'pw',
#        u'templated': True}],
#      u'pw:quotes': {u'href': u'/quotes?q=location_id:3939&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00'},
#      u'pw:reviews': {u'href': u'/locations/3939/reviews'},
#      u'self': {u'href': u'/locations/3939'},
#      u'site:purchase': None},
#     u'address1': u'300 N. State St.',
#     u'city': u'Chicago',
#     u'entrances': [{u'coordinates': [41.888432004142075, -87.62812751345336]}],
#     u'id': u'3939',
#     u'name': u'Marina Towers Garage - Valet',
#     u'photos': [{u'position': 2,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/gallery/300NState-2.jpg?1493824017',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/gallery_thumb/300NState-2.jpg?1493824017',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/hub_frontpage/300NState-2.jpg?1493824017',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/logo/300NState-2.jpg?1493824017',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/original/300NState-2.jpg?1493824017',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/res_ticket/300NState-2.jpg?1493824017',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162311/search_thumb/300NState-2.jpg?1493824017',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 0,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/gallery/300NState-1.jpg?1493824012',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/gallery_thumb/300NState-1.jpg?1493824012',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/hub_frontpage/300NState-1.jpg?1493824012',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/logo/300NState-1.jpg?1493824012',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/original/300NState-1.jpg?1493824012',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/res_ticket/300NState-1.jpg?1493824012',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162305/search_thumb/300NState-1.jpg?1493824012',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 4,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/gallery/300NState-7.jpg?1493824047',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/gallery_thumb/300NState-7.jpg?1493824047',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/hub_frontpage/300NState-7.jpg?1493824047',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/logo/300NState-7.jpg?1493824047',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/original/300NState-7.jpg?1493824047',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/res_ticket/300NState-7.jpg?1493824047',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162341/search_thumb/300NState-7.jpg?1493824047',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 1,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/gallery/300NState-6.jpg?1493824043',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/gallery_thumb/300NState-6.jpg?1493824043',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/hub_frontpage/300NState-6.jpg?1493824043',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/logo/300NState-6.jpg?1493824043',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/original/300NState-6.jpg?1493824043',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/res_ticket/300NState-6.jpg?1493824043',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162335/search_thumb/300NState-6.jpg?1493824043',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 5,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/gallery/300NState-3.jpg?1493824021',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/gallery_thumb/300NState-3.jpg?1493824021',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/hub_frontpage/300NState-3.jpg?1493824021',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/logo/300NState-3.jpg?1493824021',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/original/300NState-3.jpg?1493824021',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/res_ticket/300NState-3.jpg?1493824021',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162317/search_thumb/300NState-3.jpg?1493824021',
#         u'height': 130,
#         u'width': 130}}},
#      {u'position': 3,
#       u'sizes': {u'gallery': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/gallery/300NState-9.jpg?1493824055',
#         u'height': 534,
#         u'width': 800},
#        u'gallery_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/gallery_thumb/300NState-9.jpg?1493824055',
#         u'height': 67,
#         u'width': 100},
#        u'hub_frontpage': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/hub_frontpage/300NState-9.jpg?1493824055',
#         u'height': 300,
#         u'width': 300},
#        u'logo': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/logo/300NState-9.jpg?1493824055',
#         u'height': 100,
#         u'width': 150},
#        u'original': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/original/300NState-9.jpg?1493824055',
#         u'height': 667,
#         u'width': 1000},
#        u'res_ticket': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/res_ticket/300NState-9.jpg?1493824055',
#         u'height': 200,
#         u'width': 300},
#        u'search_thumb': {u'URL': u'https://d2uqqhmijd5j2z.cloudfront.net/files/162353/search_thumb/300NState-9.jpg?1493824055',
#         u'height': 130,
#         u'width': 130}}}],
#     u'state': u'IL'}},
#   u'distance': {u'straight_line': {u'feet': 2598, u'meters': 791}},
#   u'end_time': u'2017-12-23T20:00:00.000-06:00',
#   u'location_id': u'3939',
#   u'max_end': u'2017-12-24T00:00:00.000-06:00',
#   u'min_start': u'2017-12-23T12:00:00.000-06:00',
#   u'name': u'',
#   u'purchase_options': [{u'_links': {u'curies': [{u'href': u'https://www.parkwhiz.com/{rel}',
#        u'name': u'site',
#        u'templated': True}],
#      u'site:purchase': {u'href': u'/find_and_book/?location_id=3939&start_time=2017-12-23T12:00&end_time=2017-12-23T20:00&pwa=ee51'}},
#     u'amenities': [{u'description': u'Attended',
#       u'enabled': True,
#       u'key': u'attended',
#       u'name': u'Attended',
#       u'visible': True},
#      {u'description': u'Covered',
#       u'enabled': True,
#       u'key': u'indoor',
#       u'name': u'Covered',
#       u'visible': True},
#      {u'description': u'Valet',
#       u'enabled': True,
#       u'key': u'valet',
#       u'name': u'Valet',
#       u'visible': True},
#      {u'description': u'Accessible',
#       u'enabled': True,
#       u'key': u'handicap',
#       u'name': u'Accessible',
#       u'visible': True},
#      {u'description': u'Security',
#       u'enabled': False,
#       u'key': u'security',
#       u'name': u'Security',
#       u'visible': False},
#      {u'description': u'Restrooms',
#       u'enabled': False,
#       u'key': u'restrooms',
#       u'name': u'Restrooms',
#       u'visible': False},
#      {u'description': u'Guaranteed to be unobstructed',
#       u'enabled': False,
#       u'key': u'unobstructed',
#       u'name': u'Unobstructed',
#       u'visible': True},
#      {u'description': u'Reentry allowed',
#       u'enabled': False,
#       u'key': u'reentry',
#       u'name': u'Reentry Allowed',
#       u'visible': True},
#      {u'description': u'Electric Car Charging',
#       u'enabled': False,
#       u'key': u'vehicle_charging',
#       u'name': u'Electric Car Charging',
#       u'visible': False},
#      {u'description': u'Printed pass',
#       u'enabled': False,
#       u'key': u'printed_pass',
#       u'name': u'Printed Pass',
#       u'visible': False}],
#     u'curation_score': 127699.30148795861,
#     u'id': u'd3124528-4758-466e-8756-67f4da295152',
#     u'price': {u'USD': u'15.00'},
#     u'price_advisory': u'None',
#     u'pricing_segments': [{u'end_time': u'2017-12-23T20:00:00.000-06:00',
#       u'event': {},
#       u'id': 286033,
#       u'pricing_type': u'TransientPricing',
#       u'purchase_limit': -1,
#       u'space_availability': {u'status': u'available'},
#       u'start_time': u'2017-12-23T12:00:00.000-06:00'}],
#     u'space_availability': {u'status': u'available'},
#     u'validation': {u'require_license_plate': False,
#      u'validation_steps': [{u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77245/original/validation-icons-27.png?1453405593'},
#        u'instructions': u'Present ParkWhiz Pass to valet attendant in exchange for valet-ticket'},
#       {u'icon': {u'path': u'https://d2uqqhmijd5j2z.cloudfront.net/files/77251/original/validation-icons-05.png?1453405596'},
#        u'instructions': u'When you return, present valet-ticket to attendant (tip not included in reservation)'}]}}],
#   u'quote_type': u'transient',
#   u'seller_id': 602,
#   u'start_time': u'2017-12-23T12:00:00.000-06:00'}]

# %%
columns = ['id','name','lat','lon','coordinates','address','city','seller_id','price', 'amenity', 'accessible', 'valet', 'security', 'restrooms', 'printed_pass', 'reentry_allowed']
frame = DataFrame(columns=columns)

for i, event in enumerate(json_data):
    try:
        dict0={}
        dict0['id'] = event['_embedded']['pw:location']['id']
        dict0['name'] = event['_embedded']['pw:location']['name']
        dict0['lat'] = float(event['_embedded']['pw:location']['entrances'][0]['coordinates'][0])
        dict0['lon'] = float(event['_embedded']['pw:location']['entrances'][0]['coordinates'][1])
        dict0['coordinates'] = event['_embedded']['pw:location']['entrances'][0]['coordinates']
        dict0['address'] = event['_embedded']['pw:location']['address1']
        dict0['city'] = event['_embedded']['pw:location']['city']
        dict0['seller_id'] = event['seller_id']
        dict0['price'] = float(event['purchase_options'][0]['price']['USD'])
        # Checks if it is accessible, if there is valet, security, restrooms, printed pass, re-entry allowed
        for key in dict0:
            frame.loc[i,key] = dict0[key]
    except Exception:
        pass
frame[['lat', 'lon']].head()
# Out:
#        lat      lon
# 0  41.8852 -87.6356
# 1  41.8859 -87.6353
# 2  41.8843  -87.636
# 3  41.8879 -87.6373
# 4  41.8862  -87.634

# %%
X_train, X_test, y_train, y_test = train_test_split(frame[['lat','lon']],frame['price'],test_size=0.2,random_state=574)

# %%
knnR = KNeighborsRegressor(n_neighbors=3,metric='haversine')

# %%
knnR.fit(X_train,y_train)

# %%
from repository.mlrepositoryclient import MLRepositoryClient
from repository.mlrepositoryartifact import MLRepositoryArtifact
from repository.mlrepository import MetaProps, MetaNames

# %%
wml_credentials = {
  "url": "https://ibm-watson-ml.mybluemix.net",
  "access_key": "5eJV3UHu5LQEVQObnm8ciAywGzvSm7y47quRrlI7Luq3lOzm9fi0i9yQkv70gO54HxGxQ3pIogjgEOjN0TGDTcL0h32gVzPkwMbmHXNpi+FQYUqQmv73SQJrb1WXWeZv",
  "username": "33e97d56-995f-4f77-b0f1-646731e50702",
  "password": "3c2a4a2d-7020-46c5-a9c8-954122ac9d60",
  "instance_id": "00195eb4-c665-4384-9e21-57e59ac66f5f"
}

# %%
ml_repository_client = MLRepositoryClient(wml_credentials['url'])
ml_repository_client.authorize(wml_credentials['username'], wml_credentials['password'])

# %%
props = MetaProps({MetaNames.AUTHOR_NAME:"Aleksandar Velkoski", MetaNames.AUTHOR_EMAIL:"avelkoski@ethventures.io"})
model_artifact = MLRepositoryArtifact(knnR, name="SpotExchange KNeighborsRegressor", meta_props=props)

# %%
saved_model = ml_repository_client.models.save(model_artifact)

# %%
import urllib3, requests, json

headers = urllib3.util.make_headers(basic_auth='{username}:{password}'.format(username=wml_credentials['username'], password=wml_credentials['password']))
url = '{}/v3/identity/token'.format(wml_credentials['url'])
response = requests.get(url, headers=headers)
mltoken = json.loads(response.text).get('token')

# %%
endpoint_instance = wml_credentials['url'] + "/v3/wml_instances/" + wml_credentials['instance_id']
header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken} 

response_get_instance = requests.get(endpoint_instance, headers=header)

# %%
endpoint_published_models = json.loads(response_get_instance.text).get('entity').get('published_models').get('url')

# %%
print endpoint_published_models

# %%
header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}
response_get = requests.get(endpoint_published_models, headers=header)

# %%
print mltoken

# %%
[endpoint_deployments] = [x.get('entity').get('deployments').get('url') for x in json.loads(response_get.text).get('resources') if x.get('metadata').get('guid') == saved_model.uid]

# %%
payload_online = {"name": "knnR-SpotExchange", "description": "KNearestNeighbor Regressor for SpotExchange Price Predictions", "type": "online"}
response_online = requests.post(endpoint_deployments, json=payload_online, headers=header)

# %%
scoring_url = json.loads(response_online.text).get('entity').get('scoring_url')

print(scoring_url)

# %%
values = [[41.88523011803571, -87.63557374477386],
       [41.88593811224804, -87.6352616958502],
       [41.88427161764708, -87.63602267950773]]

# %%
payload_scoring = {"values": values}

# %%
response_scoring = requests.post(scoring_url, json=payload_scoring, headers=header)

# %%
print response_scoring.text
